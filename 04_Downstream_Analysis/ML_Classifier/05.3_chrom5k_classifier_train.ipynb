# %% [markdown]
# # Train XGBoost model

# %%
import scanpy as sc
import anndata as ad
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, log_loss
from pathlib import Path

# %%
import xgboost as xgb

# %%
import os
root_dir = Path("/tscc/projects/ps-epigen/users/biy022/scmethylhic/human_hippocampus/snm3c/hh_micro_mono/")
os.chdir(root_dir / "DMR_classifier")

# %%
adata = sc.read_h5ad("chrom5k-CGN_beta_trinarized.h5ad")
metadata = pd.read_csv("dmr_regions-CGN_hypo_score-meta_sub.tsv", sep="\t", header=0, index_col=0)

# %%
metadata["ct_raw"] = metadata["celltype"].copy()
ext = ["CA", "DG", "SUB"]
metadata.loc[metadata["celltype"].isin(ext), "celltype"] = "Exc_Neurons"
inh = ["PVALB", "SST", "VIP", "NR2F2-LAMP5"]
metadata.loc[metadata["celltype"].isin(inh), "celltype"] = "Inh_Neurons"

# %%
included_ct = [
    "Exc_Neurons", "Inh_Neurons",
    "Astro", "Oligo", "OPC", "Endo-VLMC",
    "Endo_Lym_Skn", "Fibro_Mus", "Mast_Skn", "Mono2",
    "NK_CD16_Bld", "Tnaive_CD4_1", "infant_MGC-1"
]

# %%
micro_adata = adata[metadata[metadata["celltype"].isin(["Micro1", "Micro2"])].index, :].copy()
adata = adata[metadata[metadata["celltype"].isin(included_ct)].index, :].copy()

# %%
micro_adata
# Out:
# AnnData object with n_obs × n_vars = 1000 × 606688
#     obs: 'celltype'

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 5683 × 606688
#     obs: 'celltype'

# %%
X = adata.X
y = metadata.loc[adata.obs_names, "celltype"].values
le = LabelEncoder()
y_numeric = le.fit_transform(y)

# %%
# Train: Eval: Test in 7:2:1 ratio
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y_numeric, test_size=0.1, random_state=42, stratify=y_numeric
)
X_train, X_eval, y_train, y_eval = train_test_split(
    X_temp, y_temp, test_size=2/9, random_state=42, stratify=y_temp
)

# %%
# Load data onto XGBoost GPU support
dtrain = xgb.DMatrix(X_train, label=y_train)
deval = xgb.DMatrix(X_eval, label=y_eval)
dtest = xgb.DMatrix(X_test, label=y_test)

# %% [raw]
# dtrain = xgb.DMatrix(X, label=y_numeric)

# %%
## Accuracy calculation
num_classes = len(np.unique(y_numeric))
def accuracy_eval(preds, dmatrix):
    labels = dmatrix.get_label().astype(int)
    preds = preds.reshape(-1, num_classes)
    pred_labels = np.argmax(preds, axis=1)
    acc = np.mean(pred_labels == labels)
    return "accuracy", acc

# %%
print(num_classes)
# Out:
# 13

# %%
print(len(metadata["celltype"].unique()))
# Out:
# 25

# %% [markdown]
# ## Training

# %%
params = {
    "objective": "multi:softprob",
    "num_class": num_classes,
    "tree_method": "hist",
    "device": "cuda",
    "max_depth": 5,
    "learning_rate": 0.01,
    "subsample": 0.8,
    "colsample_bytree": 0.4,
    "reg_lambda": 1.0,
    "reg_alpha": 0.5,
    "eval_metric": "mlogloss",
    "random_state": 42
}

# %%
evals = [(dtrain, "train"), (deval, "eval")]
evals_result = {}
bst = xgb.train(
    params,
    dtrain,
    num_boost_round=3000,
    evals=evals,
    custom_metric=accuracy_eval,
    evals_result=evals_result,
    early_stopping_rounds=3000,
    verbose_eval=50
)
# Out:
# [0]	train-mlogloss:2.52434	train-accuracy:0.83908	eval-mlogloss:2.52921	eval-accuracy:0.73615
# [50]	train-mlogloss:1.43282	train-accuracy:0.96857	eval-mlogloss:1.57433	eval-accuracy:0.94019
# [100]	train-mlogloss:0.95002	train-accuracy:0.97435	eval-mlogloss:1.13486	eval-accuracy:0.94987
# [150]	train-mlogloss:0.66513	train-accuracy:0.98039	eval-mlogloss:0.86245	eval-accuracy:0.95515
# [200]	train-mlogloss:0.48225	train-accuracy:0.98542	eval-mlogloss:0.67675	eval-accuracy:0.96042
# [250]	train-mlogloss:0.35929	train-accuracy:0.98869	eval-mlogloss:0.54603	eval-accuracy:0.96570
# [300]	train-mlogloss:0.27424	train-accuracy:0.99321	eval-mlogloss:0.45110	eval-accuracy:0.96658
# [350]	train-mlogloss:0.21390	train-accuracy:0.99547	eval-mlogloss:0.38043	eval-accuracy:0.96834
# [400]	train-mlogloss:0.17015	train-accuracy:0.99723	eval-mlogloss:0.32727	eval-accuracy:0.96922
# [450]	train-mlogloss:0.13751	train-accuracy:0.99899	eval-mlogloss:0.28664	eval-accuracy:0.97186
# [500]	train-mlogloss:0.11272	train-accuracy:0.99925	eval-mlogloss:0.25512	eval-accuracy:0.97098
# [550]	train-mlogloss:0.09356	train-accuracy:0.99975	eval-mlogloss:0.23061	eval-accuracy:0.97098
# [600]	train-mlogloss:0.07844	train-accuracy:0.99975	eval-mlogloss:0.21139	eval-accuracy:0.97098
# [650]	train-mlogloss:0.06644	train-accuracy:1.00000	eval-mlogloss:0.19548	eval-accuracy:0.97274
# [700]	train-mlogloss:0.05680	train-accuracy:1.00000	eval-mlogloss:0.18264	eval-accuracy:0.97274
# [750]	train-mlogloss:0.04890	train-accuracy:1.00000	eval-mlogloss:0.17233	eval-accuracy:0.97362
# [800]	train-mlogloss:0.04255	train-accuracy:1.00000	eval-mlogloss:0.16374	eval-accuracy:0.97537
# [850]	train-mlogloss:0.03727	train-accuracy:1.00000	eval-mlogloss:0.15623	eval-accuracy:0.97537
# [900]	train-mlogloss:0.03292	train-accuracy:1.00000	eval-mlogloss:0.14983	eval-accuracy:0.97625
# [950]	train-mlogloss:0.02931	train-accuracy:1.00000	eval-mlogloss:0.14453	eval-accuracy:0.97625
# [1000]	train-mlogloss:0.02630	train-accuracy:1.00000	eval-mlogloss:0.13995	eval-accuracy:0.97713
# [1050]	train-mlogloss:0.02378	train-accuracy:1.00000	eval-mlogloss:0.13579	eval-accuracy:0.97889
# [1100]	train-mlogloss:0.02166	train-accuracy:1.00000	eval-mlogloss:0.13233	eval-accuracy:0.97977
# [1150]	train-mlogloss:0.01985	train-accuracy:1.00000	eval-mlogloss:0.12907	eval-accuracy:0.97977
# [1200]	train-mlogloss:0.01830	train-accuracy:1.00000	eval-mlogloss:0.12634	eval-accuracy:0.97977
# [1250]	train-mlogloss:0.01697	train-accuracy:1.00000	eval-mlogloss:0.12396	eval-accuracy:0.97977
# [1300]	train-mlogloss:0.01585	train-accuracy:1.00000	eval-mlogloss:0.12176	eval-accuracy:0.97977
# [1350]	train-mlogloss:0.01487	train-accuracy:1.00000	eval-mlogloss:0.11971	eval-accuracy:0.97977
# [1400]	train-mlogloss:0.01401	train-accuracy:1.00000	eval-mlogloss:0.11775	eval-accuracy:0.97977
# [1450]	train-mlogloss:0.01326	train-accuracy:1.00000	eval-mlogloss:0.11600	eval-accuracy:0.97977
# [1500]	train-mlogloss:0.01259	train-accuracy:1.00000	eval-mlogloss:0.11435	eval-accuracy:0.97977
# [1550]	train-mlogloss:0.01201	train-accuracy:1.00000	eval-mlogloss:0.11285	eval-accuracy:0.98065
# [1600]	train-mlogloss:0.01149	train-accuracy:1.00000	eval-mlogloss:0.11147	eval-accuracy:0.98065
# [1650]	train-mlogloss:0.01103	train-accuracy:1.00000	eval-mlogloss:0.11008	eval-accuracy:0.98065
# [1700]	train-mlogloss:0.01060	train-accuracy:1.00000	eval-mlogloss:0.10900	eval-accuracy:0.98065
# [1750]	train-mlogloss:0.01023	train-accuracy:1.00000	eval-mlogloss:0.10785	eval-accuracy:0.98065
# [1800]	train-mlogloss:0.00989	train-accuracy:1.00000	eval-mlogloss:0.10681	eval-accuracy:0.98065
# [1850]	train-mlogloss:0.00958	train-accuracy:1.00000	eval-mlogloss:0.10585	eval-accuracy:0.98153
# [1900]	train-mlogloss:0.00929	train-accuracy:1.00000	eval-mlogloss:0.10494	eval-accuracy:0.98153
# [1950]	train-mlogloss:0.00903	train-accuracy:1.00000	eval-mlogloss:0.10404	eval-accuracy:0.98153
# [2000]	train-mlogloss:0.00879	train-accuracy:1.00000	eval-mlogloss:0.10326	eval-accuracy:0.98241
# [2050]	train-mlogloss:0.00857	train-accuracy:1.00000	eval-mlogloss:0.10251	eval-accuracy:0.98241
# [2100]	train-mlogloss:0.00836	train-accuracy:1.00000	eval-mlogloss:0.10182	eval-accuracy:0.98241
# [2150]	train-mlogloss:0.00817	train-accuracy:1.00000	eval-mlogloss:0.10111	eval-accuracy:0.98241
# [2200]	train-mlogloss:0.00799	train-accuracy:1.00000	eval-mlogloss:0.10042	eval-accuracy:0.98241
# [2250]	train-mlogloss:0.00782	train-accuracy:1.00000	eval-mlogloss:0.09983	eval-accuracy:0.98241
# [2300]	train-mlogloss:0.00767	train-accuracy:1.00000	eval-mlogloss:0.09925	eval-accuracy:0.98241
# [2350]	train-mlogloss:0.00753	train-accuracy:1.00000	eval-mlogloss:0.09873	eval-accuracy:0.98241
# [2400]	train-mlogloss:0.00739	train-accuracy:1.00000	eval-mlogloss:0.09823	eval-accuracy:0.98153
# [2450]	train-mlogloss:0.00727	train-accuracy:1.00000	eval-mlogloss:0.09778	eval-accuracy:0.98153
# [2500]	train-mlogloss:0.00715	train-accuracy:1.00000	eval-mlogloss:0.09734	eval-accuracy:0.98241
# [2550]	train-mlogloss:0.00704	train-accuracy:1.00000	eval-mlogloss:0.09690	eval-accuracy:0.98241
# [2600]	train-mlogloss:0.00693	train-accuracy:1.00000	eval-mlogloss:0.09645	eval-accuracy:0.98241
# [2650]	train-mlogloss:0.00683	train-accuracy:1.00000	eval-mlogloss:0.09603	eval-accuracy:0.98241
# [2700]	train-mlogloss:0.00674	train-accuracy:1.00000	eval-mlogloss:0.09569	eval-accuracy:0.98241
# [2750]	train-mlogloss:0.00666	train-accuracy:1.00000	eval-mlogloss:0.09536	eval-accuracy:0.98241
# [2800]	train-mlogloss:0.00658	train-accuracy:1.00000	eval-mlogloss:0.09502	eval-accuracy:0.98241
# [2850]	train-mlogloss:0.00650	train-accuracy:1.00000	eval-mlogloss:0.09471	eval-accuracy:0.98241
# [2900]	train-mlogloss:0.00643	train-accuracy:1.00000	eval-mlogloss:0.09442	eval-accuracy:0.98241
# [2950]	train-mlogloss:0.00637	train-accuracy:1.00000	eval-mlogloss:0.09416	eval-accuracy:0.98241
# [2999]	train-mlogloss:0.00630	train-accuracy:1.00000	eval-mlogloss:0.09391	eval-accuracy:0.98241

# %%
eval_logloss = evals_result["eval"]["mlogloss"]
best_iter = int(np.argmin(eval_logloss))
print(best_iter)
best_score = float(np.min(eval_logloss))
# Out:
# 2999

# %%
bst.save_model("models/chrom5k_trinarize_20251017.json")

# %% [markdown]
# ## After training

# %%
bst = xgb.Booster()
bst.load_model("models/chrom5k_trinarize_20251017.json")

# %%
best_iter = 2999
y_pred_proba = bst.predict(dtest, iteration_range=(0, best_iter + 1))
y_pred = np.argmax(y_pred_proba, axis=1)

# %%
order = included_ct

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import confusion_matrix

# Create heatmap
cm = confusion_matrix(y_test, y_pred, normalize="true") * 100
cm_df = pd.DataFrame(cm, index=le.classes_, columns=le.classes_)
cm_df = cm_df.loc[order, order]
plt.figure(figsize=(6, 4), dpi=150)
sns.heatmap(
    cm_df,
    cmap="Blues",
    cbar_kws={"label": "% of True Class"},
    square=True,
    annot=False,
    linewidths=0.5
)

plt.title("Confusion Matrix Heatmap (% of True Class)")
plt.xlabel("Predicted Cell Type")
plt.ylabel("True Cell Type")
plt.tight_layout()
plt.show()

# %%
micro_adata = sc.read_h5ad("chrom5k-CGN_beta_trinarized-Micro_subtypes_test.h5ad")

# %%
micro_adata
# Out:
# AnnData object with n_obs × n_vars = 2634 × 606688
#     obs: 'celltype'

# %%
dmicro = xgb.DMatrix(micro_adata.X)

# %%
micro_pred_prob = bst.predict(dmicro, iteration_range=(0, best_iter + 1))
micro_pred = np.argmax(micro_pred_prob, axis=1)

# %%
pred_df = pd.DataFrame({
    "cell_id": micro_adata.obs_names,
    "true_type": micro_adata.obs["celltype"],
    "predicted_type": le.inverse_transform(micro_pred),
})

# %%
plt.figure(figsize=(6, 4), dpi=125)
sns.countplot(data=pred_df, x="predicted_type", hue="true_type", order=order, edgecolor="black")
plt.title("Predicted Cell Type Distribution for New Cell Types")
plt.xlabel("Predicted (Trained Model Classes)")
plt.ylabel("Cell Count")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
from scipy.signal import savgol_filter
from scipy.ndimage import gaussian_filter1d
# proba_df = pd.DataFrame(
#     gaussian_filter1d(micro_pred_prob, sigma=1, axis=1, mode="nearest"),
#     columns=le.classes_,
#     index=micro_adata.obs_names
# )
proba_df = pd.DataFrame(micro_pred_prob, columns=le.classes_)
proba_df["celltype"] = micro_adata.obs["celltype"].values
proba_df["cell_id"] = micro_adata.obs_names.values
proba_long = proba_df.melt(
    id_vars=["cell_id", "celltype"],
    var_name="predicted_class",
    value_name="probability"
)
proba_long["predicted_class"] = pd.Categorical(proba_long["predicted_class"], categories=order)

# %%
plt.figure(figsize=(8, 4))
sns.lineplot(
    data=proba_long,
    x="predicted_class",
    y="probability",
    hue="celltype",
    units="cell_id",
    estimator=None,
    lw=1,
    alpha=0.05,
)

plt.xticks(rotation=45, ha="right")
plt.ylabel("Predicted probability")
plt.xlabel("Predicted class")
plt.title("Predicted probability distribution across classes per cell")
plt.legend(title="True cell type", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %%
meta_raw = pd.read_csv("allc_meta.tsv", sep="\t", header=0, index_col=0)

# %%
entropy = -np.sum(micro_pred_prob * np.log(micro_pred_prob + 1e-12), axis=1)
entropy /= np.log(micro_pred_prob.shape[1])
sorted_prob = np.sort(micro_pred_prob, axis=1)
margin = sorted_prob[:, -1] - sorted_prob[:, -2]
proba_max_value = pd.DataFrame({
    "max_value": np.max(micro_pred_prob, axis=1),
    "entropy": entropy,
    "margin": margin,
    "celltype": micro_adata.obs["celltype"].values,
    "prediction": le.inverse_transform(micro_pred),
    "cell_id": micro_adata.obs_names,
    "cov": meta_raw.loc[micro_adata.obs_names, "total_cov"]
})

# %%
confident_cells = proba_max_value[proba_max_value["cov"] >= 0.7e5]["cell_id"]

# %%
plt.figure(figsize=(6, 4), dpi=125)
sns.countplot(
    data=pred_df[pred_df["cell_id"].isin(confident_cells)], 
    x="predicted_type", 
    hue="true_type", 
    order=order, 
    edgecolor="black"
)
plt.title("Predicted Cell Type Distribution for New Cell Types")
plt.xlabel("Predicted (Trained Model Classes)")
plt.ylabel("Cell Count")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.lineplot(
    data=proba_long[proba_long["cell_id"].isin(confident_cells)],
    x="predicted_class",
    y="probability",
    hue="celltype",
    units="cell_id",
    estimator=None,
    lw=1,
    alpha=0.05,
)

plt.xticks(rotation=45, ha="right")
plt.ylabel("Predicted probability")
plt.xlabel("Predicted class")
plt.title("Predicted probability distribution across classes per cell")
plt.legend(title="True cell type", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %%
pred_df[pred_df["cell_id"].isin(confident_cells)].to_csv(
    "results/chrom5k_trinarize_20251017-micro_subtype-prediction.tsv",
    sep="\t", header=True, index=True
)

# %%
df = proba_long[proba_long["cell_id"].isin(confident_cells)].copy()
df.to_csv("results/chrom5k_trinarize_20251017-micro_subtype-pred_prob.tsv", sep="\t", header=True, index=True)

# %% [markdown]
# # Plot important regions

# %%
bst = xgb.Booster()
bst.load_model("models/trinarize_20251013.json")

# %%
importance = bst.get_score(importance_type="gain")
importance_df = (
    pd.DataFrame(list(importance.items()), columns=["feature", "importance"])
    .sort_values("importance", ascending=False)
    .reset_index(drop=True)
)

# %%
importance_df.shape
# Out:
# (51847, 2)

# %%
topN = int(importance_df.shape[0] * 0.01)
importance_df["region"] = [adata.var_names[int(f[1:])] for f in importance_df["feature"]]
top_regions = importance_df["region"].head(topN).values

# %%
metadata = pd.read_csv("allc_meta.tsv", sep="\t", header=0, index_col=0)
metadata["ct_raw"] = metadata["celltype"].copy()
ext = ["CA", "DG", "SUB"]
metadata.loc[metadata["celltype"].isin(ext), "celltype"] = "Exc_Neurons"
inh = ["PVALB", "SST", "VIP", "NR2F2-LAMP5"]
metadata.loc[metadata["celltype"].isin(inh), "celltype"] = "Inh_Neurons"

# %%
from ALLCools.mcds import MCDS

# %%
mcds_path = "DMR_CLS.mcds"
var_dim = "dmr_regions"
obs_dim = "cell"
mcds = MCDS.open(mcds_path, obs_dim=obs_dim, var_dim=var_dim)
mcds.add_cell_metadata(metadata)

# %%
included_ct = [
    "Exc_Neurons", "Inh_Neurons",
    "Astro", "Oligo", "OPC", "Endo-VLMC",
    "Endo_Lym_Skn", "Fibro_Mus", "Mast_Skn", "Mono2",
    "NK_CD16_Bld", "Tnaive_CD4_1", "infant_MGC-1"
]

# %%
order = included_ct

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import confusion_matrix

# %%
top_regions = top_regions[np.argsort([int(xx.split("_")[-1]) for xx in top_regions])]

# %%
da = mcds["dmr_regions_da"]
mc = da.sel(mc_type="CGN", count_type="mc")
cov = da.sel(mc_type="CGN", count_type="cov")
mc_bulk = mc.groupby("cell_celltype").sum(dim="cell")
cov_bulk = cov.groupby("cell_celltype").sum(dim="cell")
bulk_beta_sel = 1.0 - mc_bulk.sel(dmr_regions=top_regions) / cov_bulk.sel(dmr_regions=top_regions)

# %%
bulk_beta_sel = bulk_beta_sel.to_pandas()

# %%
order = included_ct
order = order + ["Micro1", "Micro2"]
df_beta = bulk_beta_sel[bulk_beta_sel.index.isin(order)]
# df_beta = df_beta.loc[order, sorted_columns]
region_order = df_beta.idxmax(axis=0)
region_order = pd.Categorical(region_order, categories=order, ordered=True)
df_beta = df_beta.iloc[:, np.argsort(region_order.codes)]
df_beta = df_beta.loc[order, :]
df_beta_z = (df_beta - df_beta.mean()) / df_beta.std()

# %%
plt.figure(figsize=(6, 4), dpi=125)
sns.heatmap(
    df_beta_z,
    cmap="coolwarm",
    center=0,
    xticklabels=False,
    vmin=-2, 
    vmax=2,
    cbar_kws={"label": "Pseudo-bulk β"},
)
plt.xlabel("Regions")
plt.ylabel("Cell Type")
plt.title("Pseudo-bulk methylation of top important regions")
plt.tight_layout()
plt.show()
